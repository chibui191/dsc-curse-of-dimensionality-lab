# %% [markdown]
# # The Curse of Dimensionality - Lab
#
# ## Introduction
#
# In this lab, you'll conduct some mathematical simulations to further investigate the consequences of the curse of dimensionality.
#
# ## Objectives
#
# In this lab you will:
#
# - Create and interpret a visual demonstrating how sparsity changes with n for n-dimensional spaces
# - Demonstrate how training time increases exponentially as the number of features increases

# %% [markdown]
# ## Sparseness in N-Dimensional Space
#
# As discussed, points in n-dimensional space become increasingly sparse as the number of dimensions increases. To demonstrate this, you'll write a function to calculate the Euclidean distance between two points. From there, you'll then generate random points in n-dimensional space, calculate their average distance from the origin, and plot the relationship between this average distance and n.

# %% [markdown]
# ## Euclidean Distance
#
# To start, write a function which takes two points, p1 and p2, and returns the Euclidean distance between them. Recall that the Euclidean distance between two points is given by:
#
# $$ d(a,b) = \sqrt{(a_1 - b_1)^2 + (a_2 - b_2)^2 + ... + (a_n - b_n)^2} $$

# %%
import numpy as np

# %%
def euclidean_distance(p1, p2):
    p1 = np.array(p1)
    p2 = np.array(p2)
    return np.sqrt(sum((p1 - p2)**2))

# %% [markdown]
# ## Average Distance From the Origin
#
# To examine the curse of dimensionality, you'll investigate the average distance to the center of n-dimensional space. As you'll see, this average distance increases as the number of dimensions increases. To investigate this, generate 100 random points for various n-dimensional spaces. Investigate n-dimensional spaces from n=1 to n=1000. In each of these, construct the 100 random points using a random number between -10 and 10 for each dimension of the point. From there, calculate the average distance from each of these points to the origin. Finally, plot this relationship on a graph; the x-axis will be n, the number of dimensions, and the y-axis will be the average distance from the origin.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
# Your code here
dimensions = np.arange(1,1001)
avg_distances = []

for d in dimensions:
    origin = np.zeros(d)
    pts = [np.random.uniform(low=-10, high=10, size=d) for i in range(100)]
    avg_distances.append(np.mean([euclidean_distance(origin, pt) for pt in pts]))

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.plot(dimensions, avg_distances)
plt.xlabel('Dimensions')
plt.ylabel('Average Distance from the Origin')
plt.show();

# %% [markdown]
# ## Convergence Time
#
# As mentioned before, another issue with increasing the dimension of the feature space is the training time required to fit a machine learning model. While more data will generally lead to better predictive results, it will also substantially increase training time. To demonstrate this, generate lists of random numbers as you did above. Then, use this list of random numbers as a feature in a mock dataset; choose an arbitrary coefficient and multiply the feature vector by this coefficient. Then, sum these feature-coefficient products to get an output, `y`. To spice things up (and not have a completely deterministic relationship), add a normally distributed white noise parameter to your output values. Fit an ordinary least squares model to your generated mock data. Repeat this for a varying number of features, and record the time required to fit the model. (Be sure to only record the time to train the model, not the time to generate the data.) Finally, plot the number of features, n, versus the training time for the subsequent model.

# %%
import pandas as pd
import datetime
from sklearn.linear_model import LinearRegression, Lasso

# %%
np.random.uniform(low=-10, high=10, size=3)
# Out:
# array([-4.32686478,  8.24185967,  1.65982822])

# %%
np.random.uniform(size=3)
# Out:
# array([0.14740465, 0.78756465, 0.1288415 ])

# %%
np.array([1,2,3]) + np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
# ⏰ Your code may take some time to run

sample_size = 10**3
dimensions = np.arange(1,1001)
avg_distances = []
times = []

for d in dimensions:
    # generate random coefficient vector
    coefs = np.random.uniform(size=d)
    
    # generate random values for X
    X = [np.random.uniform(low=-10, high=10, size=d) for i in range(sample_size)]
    
    # calculate y (including white noise)
    y = np.array([np.dot(coefs, x_i) for x_i in X]) + np.random.normal(loc=0, scale=0.1, size=sample_size)
    
    ols = LinearRegression()
    # get start time
    start = datetime.datetime.now()
    # fit ols to X and y
    ols.fit(X, y)
    # get end time
    end = datetime.datetime.now()
    
    # get training time & append to 'times' list
    duration = end - start
    times.append(duration)

# %%
times[0].total_seconds()
# Out:
# 0.002279

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.plot(dimensions, [t.total_seconds() for t in times])
plt.xlabel('Dimensions')
plt.ylabel('Ordinary Least Squares Models Training Times (in seconds)')
plt.show();

# %% [markdown]
# - Repeat the same experiment for a Lasso penalized regression model

# %%
# ⏰ Your code may take some time to run 

sample_size = 10**3
dimensions = np.arange(1,1001)
avg_distances = []
times = []

for d in dimensions:
    # generate random coefficient vector
    coefs = np.random.uniform(size=d)
    
    # generate random values for X
    X = [np.random.uniform(low=-10, high=10, size=d) for i in range(sample_size)]
    
    # calculate y (including white noise)
    y = np.array([np.dot(coefs, x_i) for x_i in X]) + np.random.normal(loc=0, scale=0.1, size=sample_size)
    
    lasso = Lasso()
    # get start time
    start = datetime.datetime.now()
    # fit ols to X and y
    lasso.fit(X, y)
    # get end time
    end = datetime.datetime.now()
    
    # get training time & append to 'times' list
    duration = end - start
    times.append(duration)

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.plot(dimensions, [t.total_seconds() for t in times])
plt.xlabel('Dimensions')
plt.ylabel('Lasso Models Training Times (in seconds)')
plt.show();

# %% [markdown]
# ## Optional (Level Up)
#
# ### Show Just How Slow it Can Go!
#
# If you're up for putting your computer through the wringer and are very patient to allow the necessary computations, try increasing the maximum n from 1000 to 10,000 using Lasso regression. You should see an interesting pattern unveil. See if you can make any hypotheses as to why this might occur!
#
# _Note:_ ⏰ _You can expect your code to take over an hour to run on a 2.7 GHz speed CPU!_

# %%
# ⏰ Your code may take some time to run 
sample_size = 10**3
dimensions = np.arange(1,10001)
avg_distances = []
times = []

for d in dimensions:
    # generate random coefficient vector
    coefs = np.random.uniform(size=d)
    
    # generate random values for X
    X = [np.random.uniform(low=-10, high=10, size=d) for i in range(sample_size)]
    
    # calculate y (including white noise)
    y = np.array([np.dot(coefs, x_i) for x_i in X]) + np.random.normal(loc=0, scale=0.1, size=sample_size)
    
    lasso = Lasso()
    # get start time
    start = datetime.datetime.now()
    # fit ols to X and y
    lasso.fit(X, y)
    # get end time
    end = datetime.datetime.now()
    
    # get training time & append to 'times' list
    duration = end - start
    times.append(duration)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5378.72796606577, tolerance: 3127.9188725642834
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3426.0428104029743, tolerance: 3093.5245340592182
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3927.7794891414305, tolerance: 3098.970304960133
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4320.577548163754, tolerance: 2988.1669453982227
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3738.189399198891, tolerance: 3144.685819295383
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3451.2372384313094, tolerance: 3087.290103092823
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3909.1808181053275, tolerance: 3108.936241244278
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3934.73691040037, tolerance: 2985.8965129134785
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4267.39637682811, tolerance: 3168.988950957566
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3316.354294150253, tolerance: 3178.934840109242
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3624.4771920811436, tolerance: 3018.225194369224
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3950.8120290370716, tolerance: 3122.264541630876
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3883.972848642323, tolerance: 2981.115256427391
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3172.838016882539, tolerance: 3069.592850807332
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3738.238898858199, tolerance: 3256.425321018255
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4495.715474385157, tolerance: 3259.9439918962235
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3499.3104413980836, tolerance: 3373.1155859143855
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3641.0994634683084, tolerance: 3178.0837600189216
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3536.370264931651, tolerance: 3102.4915133195336
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4294.7134120325245, tolerance: 3083.458432432044
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3209.7579939085117, tolerance: 3111.811676761757
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3502.7961011727857, tolerance: 3058.660097981016
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3267.9356253405713, tolerance: 3232.694808131212
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3235.802267342886, tolerance: 3205.122751835918
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3604.725124822202, tolerance: 3332.9701080619557
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3502.5014676312385, tolerance: 3211.668773041629
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4163.418071532142, tolerance: 3176.543109754595
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4809.914981077851, tolerance: 3041.3304785037285
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5043.741977839985, tolerance: 3094.09620934359
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3120.0017147241415, tolerance: 2943.702310334734
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3839.963845051352, tolerance: 3013.872050746576
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3295.0269710466964, tolerance: 3249.1365254205352
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3674.993697208396, tolerance: 3255.712951878549
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3350.052214818781, tolerance: 3132.8866454481117
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3226.6859247096363, tolerance: 3213.203462800343
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3755.3225480560977, tolerance: 3232.574422930179
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3562.143433552752, tolerance: 3351.8466428344486
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3952.7252454919217, tolerance: 3373.1699009269396
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3951.776218650055, tolerance: 3420.835335132435
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3660.774670639512, tolerance: 3359.3559293321478
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3841.610028171359, tolerance: 3136.674355404795
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5161.462872806158, tolerance: 3404.463014839031
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2955.220982202998, tolerance: 2876.6193159029767
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4824.854473606731, tolerance: 3159.0235155609153
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3674.7634044903607, tolerance: 3457.3950204993653
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3341.6814785347124, tolerance: 3154.705945886372
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3571.402005667798, tolerance: 3069.2183789919227
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3578.4244510308636, tolerance: 3187.6468898670737
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4534.91745527742, tolerance: 3446.5689891702705
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721.2430121365396, tolerance: 3185.311551686807
#   model = cd_fast.enet_coordinate_descent(

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.plot(dimensions, [t.total_seconds() for t in times])
plt.xlabel('Dimensions')
plt.ylabel('Lasso Models Training Times (in seconds)')
plt.show();

# %% [markdown]
# ## Summary
#
# In this lab, you conducted various simulations to investigate the curse of dimensionality. This demonstrated some of the caveats of working with large datasets with an increasing number of features. With that, the next section will explore principal component analysis, a means of reducing the number of features in a dataset while preserving as much information as possible.
